# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_vist = pd.read_csv('Hospital Outpatient Data_NH_cleaned.zip')

# %%
df_vist.corr()
# Out:
# /var/folders/pj/y74qx7cd4y704fw6z5g1ptqc0000gn/T/ipykernel_6423/1327496321.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_vist.corr()
#                       Patient_ID       Age  Has_Insurance  Postcode  \
# Patient_ID              1.000000 -0.000282       0.001863 -0.000894
# Age                    -0.000282  1.000000       0.000287 -0.000665
# Has_Insurance           0.001863  0.000287       1.000000 -0.000468
# Postcode               -0.000894 -0.000665      -0.000468  1.000000
# Total_Cost             -0.000919 -0.000826      -0.688325 -0.000118
# Registration Minutes   -0.000644 -0.000126      -0.001063  0.001181
# Nursing Minuts          0.000219 -0.000701       0.001272  0.000303
# Laboratory Minutes     -0.000059  0.001574      -0.000090 -0.001502
# Consultation Minutes    0.000355 -0.001797      -0.001078 -0.001095
# Pharmacy Minutes        0.001745 -0.000964       0.000481 -0.000755
#
#                       Total_Cost  Registration Minutes  Nursing Minuts  \
# Patient_ID             -0.000919             -0.000644        0.000219
# Age                    -0.000826             -0.000126       -0.000701
# Has_Insurance          -0.688325             -0.001063        0.001272
# Postcode               -0.000118              0.001181        0.000303
# Total_Cost              1.000000              0.317479        0.315883
# Registration Minutes    0.317479              1.000000        0.000430
# Nursing Minuts          0.315883              0.000430        1.000000
# Laboratory Minutes      0.315693             -0.000526        0.001344
# Consultation Minutes    0.316039              0.001286        0.001269
# Pharmacy Minutes        0.314457              0.000708       -0.001245
#
#                       Laboratory Minutes  Consultation Minutes  \
# Patient_ID                     -0.000059              0.000355
# Age                             0.001574             -0.001797
# Has_Insurance                  -0.000090             -0.001078
# Postcode                       -0.001502             -0.001095
# Total_Cost                      0.315693              0.316039
# Registration Minutes           -0.000526              0.001286
# Nursing Minuts                  0.001344              0.001269
# Laboratory Minutes              1.000000             -0.001155
# Consultation Minutes           -0.001155              1.000000
# Pharmacy Minutes               -0.001232             -0.002343
#
#                       Pharmacy Minutes
# Patient_ID                    0.001745
# Age                          -0.000964
# Has_Insurance                 0.000481
# Postcode                     -0.000755
# Total_Cost                    0.314457
# Registration Minutes          0.000708
# Nursing Minuts               -0.001245
# Laboratory Minutes           -0.001232
# Consultation Minutes         -0.002343
# Pharmacy Minutes              1.000000
